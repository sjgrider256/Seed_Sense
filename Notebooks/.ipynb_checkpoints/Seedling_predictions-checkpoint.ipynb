# %%
import os
import torch
import pandas as pd
import numpy as np
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import rasterio
import geopandas as gpd
from shapely.geometry import Point

# %%
# if running notebook individually, set working directory to match root
#current_dir = os.getcwd()

# move up one level to 'Seed_Sense'
#if os.path.basename(current_dir) == "Notebooks":
 #   os.chdir("..")

#print(f"Working directory reset to: {os.getcwd()}")
# Out:
# Working directory reset to: C:\Seed_Sense

# %%
pred_tile_dir = os.path.join("Data", "Tiles")
index_csv_path = os.path.join("Data", "Tiles", "tile_index.csv")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#BUILD CenterNet MODEL: hourglass architecture

import torch.nn as nn
import torch.nn.functional as F


class ConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

class HourglassCenterNetTiny(nn.Module):
    def __init__(self, out_channels=3):
        super().__init__()

        # ------------------
        # Encoder
        # ------------------
        self.enc1 = ConvBlock(3, 32)
        self.down1 = nn.Conv2d(32, 64, 3, stride=2, padding=1)   # /2

        self.enc2 = ConvBlock(64, 64)
        self.down2 = nn.Conv2d(64, 128, 3, stride=2, padding=1)  # /4

        self.enc3 = ConvBlock(128, 128)
        self.down3 = nn.Conv2d(128, 256, 3, stride=2, padding=1) # /8

        # ------------------
        # Bottleneck
        # ------------------
        self.bottleneck = nn.Sequential(
            ConvBlock(256, 256),
            ConvBlock(256, 256)
        )

        # ------------------
        # Decoder (ONLY up to stride 8)
        # ------------------
        self.up = nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1)  # /4
        self.dec = ConvBlock(128 + 128, 128)

        # ------------------
        # Output head (stride 8!)
        # ------------------
        self.head = nn.Conv2d(128, out_channels, 1)

    def forward(self, x):
        # Encoder
        e1 = self.enc1(x)
        x = F.relu(self.down1(e1))

        e2 = self.enc2(x)
        x = F.relu(self.down2(e2))

        e3 = self.enc3(x)
        x = F.relu(self.down3(e3))  # stride 8

        # Bottleneck
        x = self.bottleneck(x)

        # Decoder (back to stride 8)
        x = self.up(x)              # stride 4
        x = self.dec(torch.cat([x, e3], dim=1))
        x = F.max_pool2d(x, 2)      # back to stride 8

        return self.head(x)
        
model = HourglassCenterNetTiny().to(device)

weights_path = "seedling_hourglass_weights.pth"

if not os.path.exists(weights_path):
    raise FileNotFoundError(f"Missing model weights: {weights_path}")

model.load_state_dict(torch.load(weights_path, map_location=device))
model.eval()
# Out:
# HourglassCenterNetTiny(
#   (enc1): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (down1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (enc2): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (down2): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (enc3): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
from torch.utils.data import DataLoader

class PredictionJPGDataset(Dataset):
    def __init__(self, img_dir, index_csv, transforms=None):
        self.img_dir = img_dir
        self.df = pd.read_csv(index_csv)
        self.image_list = self.df['tile'].tolist()
        self.transforms = transforms

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        # Change the extension from the CSV list to .jpg
        fname = self.image_list[idx].replace('.tif', '.jpg')
        img_path = os.path.join(self.img_dir, fname)

        # Check if the file exists and is the right size
        if not os.path.exists(img_path):
            return self.__getitem__((idx + 1) % len(self.image_list))

        img = Image.open(img_path).convert("RGB")

        # Skip edge tiles (not 1024x1024)
        if img.size != (1024, 1024):
            return self.__getitem__((idx + 1) % len(self.image_list))

        if self.transforms:
            img = self.transforms(img)

        return img, fname

#Standard ToTensor: scales 0-255 to 0.0-1.0
predict_dataset = PredictionJPGDataset(pred_tile_dir, index_csv_path, transforms=transforms.ToTensor())
# Re-initialize the loader
predict_loader = DataLoader(predict_dataset, batch_size=4, shuffle=False)

print(f"Total tiles in index: {len(predict_dataset)}")
print("Note: Partial edge tiles will be skipped automatically during iteration.")
# Out:
# Total tiles in index: 660
# Note: Partial edge tiles will be skipped automatically during iteration.

# %%
#decode centers function

import torch
import torch.nn.functional as F

@torch.no_grad()
def decode_centers(preds, stride=8, conf_thresh=0.15, maxpool_ks=7, topk=300, min_dist=100):
    """
    preds: [B, 3, gh, gw] raw model outputs (logits for heat)
    stride: Output stride of the model
    conf_thresh: Minimum confidence to consider a peak
    maxpool_ks: Kernel size for initial grid-based NMS
    topk: Maximum points per image before radial filtering
    min_dist: Minimum pixel distance allowed between any two detections
    """
    heat_logits = preds[:, 0:1, :, :]
    dx = preds[:, 1:2, :, :]
    dy = preds[:, 2:3, :, :]

    heat = torch.sigmoid(heat_logits)

    # 1. Grid-level Local Maxima Suppression
    pad = maxpool_ks // 2
    pooled = F.max_pool2d(heat, kernel_size=maxpool_ks, stride=1, padding=pad)
    # Mask for pixels that are the local maximum AND above threshold
    keep_mask = (heat == pooled) & (heat >= conf_thresh)

    B, _, gh, gw = heat.shape
    results = []

    for b in range(B):
        # Extract indices of peaks
        ys, xs = torch.where(keep_mask[b, 0])
        if ys.numel() == 0:
            results.append(torch.zeros((0, 2), device=preds.device))
            continue

        # Get scores for sorting
        scores = heat[b, 0, ys, xs]

        # Initial Top-K crop to keep NMS fast
        if ys.numel() > topk:
            top_idx = torch.topk(scores, k=topk).indices
            ys, xs, scores = ys[top_idx], xs[top_idx], scores[top_idx]

        # 2. Coordinate Reconstruction
        offx = dx[b, 0, ys, xs].clamp(0, 1)
        offy = dy[b, 0, ys, xs].clamp(0, 1)

        px = (xs.float() + offx) * stride
        py = (ys.float() + offy) * stride

        # Combine into [N, 3] -> (x, y, score)
        current_preds = torch.stack([px, py, scores], dim=1)

        # 3. Radial NMS
        # Sort by confidence descending so we keep the "center" of the shrub
        _, sort_idx = current_preds[:, 2].sort(descending=True)
        current_preds = current_preds[sort_idx]

        keep_indices = []
        # Ensure mask is on the same GPU/CPU as the data
        used_mask = torch.zeros(current_preds.shape[0], dtype=torch.bool, device=preds.device)

        for i in range(current_preds.shape[0]):
            if used_mask[i]:
                continue

            keep_indices.append(i)

            # Calculate Euclidean distance to all other points
            dists = torch.sqrt(
                (current_preds[i, 0] - current_preds[:, 0])**2 +
                (current_preds[i, 1] - current_preds[:, 1])**2
            )

            # Flag all points within the forbidden radius
            used_mask |= (dists < min_dist)

        final_points = current_preds[keep_indices, :2]
        results.append(final_points)

    return results

# %%
model.eval()
all_predictions = {}

print("Running predictions on JPGs...")

with torch.no_grad():
    for imgs, fnames in predict_loader:
        imgs = imgs.to(device)
        preds = model(imgs)

        # The decode_centers function expects raw logits and handles sigmoid internally.
        # So we pass the original 'preds' which contains heatmap logits and offsets.
        decoded_list = decode_centers(
            preds,
            stride=8,
            conf_thresh=0.4,
            min_dist=100
        )

        for i, detections in enumerate(decoded_list):
            all_predictions[fnames[i]] = detections

print(f"Done! Processed {len(all_predictions)} tiles.")
# Out:
# Running predictions on JPGs...
# Done! Processed 602 tiles.

# %%
#save predictions as shapefile

all_points = []

print("Converting pixel predictions to geographic coordinates...")

for tif_name, points in all_predictions.items():
    # Map the JPG name back to the original TIF path
    original_tif = os.path.join(pred_tile_dir, tif_name.replace('.jpg', '.tif'))

    if not os.path.exists(original_tif):
        continue

    with rasterio.open(original_tif) as src:
        tile_transform = src.transform
        tile_crs = src.crs

        for p in points:
            # Convert GPU tensor elements to Python floats
            px, py = p[0].cpu().item(), p[1].cpu().item()

            # rasterio transforms map coordinates
            # ~src.transform maps (lon, lat) -> (px, py)
            # src.transform maps (px, py) -> (lon, lat)
            gx, gy = tile_transform * (px, py)

            all_points.append({
                'geometry': Point(gx, gy),
                'tile': tif_name,
                'confidence': 1.0 # As decode_centers returns only px, py
            })

# Create a GeoDataFrame
if all_points:
    gdf = gpd.GeoDataFrame(all_points, crs=tile_crs)

    # Save
    output_shp = os.path.join("Data", "Output", "all_seedling_predictions.shp")
    gdf.to_file(output_shp)
    print(f"Success! Saved {len(gdf)} seedlings to {output_shp}")
else:
    print("No points found to save.")
# Out:
# Converting pixel predictions to geographic coordinates...
# Success! Saved 2891 seedlings to Data\Output\all_seedling_predictions.shp
